# %% [markdown]
# <a href="https://colab.research.google.com/github/826aryan/plannet_selling/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Housing 2.csv')

# %%
df.sample(20)
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 313  4095000  3680         3          2        2      yes        no       no
# 295  4200000  2325         3          1        2       no        no       no
# 45   7560000  6000         3          2        3      yes        no       no
# 81   6615000  4000         3          2        2      yes        no      yes
# 422  3360000  3720         2          1        1       no        no       no
# 405  3465000  3060         3          1        1      yes        no       no
# 358  3745000  3480         2          1        1      yes        no       no
# 447  3150000  3500         2          1        1       no        no      yes
# 299  4200000  7000         3          1        1      yes        no       no
# 50   7420000  7440         3          2        4      yes        no       no
# 169  5250000  6540         4          2        2       no        no       no
# ...

# %%
df['price'].mean()
# Out:
# np.float64(4766729.247706422)

# %%
import seaborn as sns

# %%
sns.distplot(df['price'])
# Out:
# /tmp/ipython-input-444587821.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
df['price'].skew()
# Out:
# np.float64(1.2122388370279802)

# %%
df['price'].kurt()
# Out:
# np.float64(1.9601302314151994)

# %%
core = df.corr(numeric_only=True)

# %%
sns.set(font_scale=1.25)

# %%
core
# Out:
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.535997  0.366494   0.517545  0.420712  0.384394
# area       0.535997  1.000000  0.151858   0.193820  0.083996  0.352980
# bedrooms   0.366494  0.151858  1.000000   0.373930  0.408564  0.139270
# bathrooms  0.517545  0.193820  0.373930   1.000000  0.326165  0.177496
# stories    0.420712  0.083996  0.408564   0.326165  1.000000  0.045547
# parking    0.384394  0.352980  0.139270   0.177496  0.045547  1.000000

# %%
sns.heatmap(core,vmax=.8,cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10})
# Out:
# <Axes: >

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)

# %%
total
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
percent
# Out:
# price               0.0
# area                0.0
# bedrooms            0.0
# bathrooms           0.0
# stories             0.0
# mainroad            0.0
# guestroom           0.0
# basement            0.0
# hotwaterheating     0.0
# airconditioning     0.0
# parking             0.0
# prefarea            0.0
# furnishingstatus    0.0
# dtype: float64

# %%
missingdata= pd.concat([total,percent],axis=1,keys=['Toatal','Percent'])

# %%
missingdata
# Out:
#                   Toatal  Percent
# price                  0      0.0
# area                   0      0.0
# bedrooms               0      0.0
# bathrooms              0      0.0
# stories                0      0.0
# mainroad               0      0.0
# guestroom              0      0.0
# basement               0      0.0
# hotwaterheating        0      0.0
# airconditioning        0      0.0
# parking                0      0.0
# prefarea               0      0.0
# furnishingstatus       0      0.0
